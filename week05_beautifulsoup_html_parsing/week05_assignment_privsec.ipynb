# %% [markdown]
# # Week 05 — Pandas for Descriptive Stats (Research-friendly)
#
# **Time budget:** ~2 hours
# **Goal:** Load scraped data into pandas and compute descriptive statistics and simple plots.
#
# **Theme (PhD focus):** Human factors of privacy & security — scraping public pages (privacy policies, cookie notices, security help pages, standards/regulator guidance) and extracting *UX-relevant* signals.
#
# ---

# %% [markdown]
# ## Deliverables
# - A completed notebook with working code
# - A dataset variable (`rows` or `df`) saved to disk (CSV/JSON depending on week)
# - 3–5 bullet reflection grounded in human factors/privacy-security research

# %% [markdown]
# ## Responsible scraping note (important)
# We will only scrape **public pages** and keep the volume small.
# - Prefer a few pages, not thousands
# - Respect robots.txt/Terms of Service when you scale later
# - Avoid collecting personal data
# - Add delays for politeness when doing multi-page work

# %% [markdown]
# ## Step 0 — Imports

# %%
import re
import time
import json
from urllib.parse import urljoin, urlparse

import requests
from bs4 import BeautifulSoup

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 1 — Load your saved JSON/CSV into pandas

# %%
# TODO: update filename to your Week 4 export
with open("week04_rows.json", "r", encoding="utf-8") as f:
    rows = json.load(f)

df = pd.DataFrame(rows)
df.head()

# %% [markdown]
# ## Step 2 — Descriptive stats + plots

# %%
df.describe(include="all")

# %%
# TODO: choose one boolean cue column to count
# Example: df["cookies"].value_counts() if you have it

# %%
# TODO: plot a distribution if you have a numeric column like num_headings
# df["num_headings"].dropna().plot(kind="hist", title="num_headings")
# plt.show()

# %% [markdown]
# ## Reflection: what would you report?

# %% [markdown]
# - Which descriptive statistic best supports a human factors argument?
